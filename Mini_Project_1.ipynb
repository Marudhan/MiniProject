# %% [markdown]
# <a href="https://colab.research.google.com/github/Marudhan/Mini-Project-/blob/main/Mini_Project_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df1=pd.read_csv("/us.csv")
df1
# Out:
#            date     cases  deaths
# 0    2020-01-21         1       0
# 1    2020-01-22         1       0
# 2    2020-01-23         1       0
# 3    2020-01-24         2       0
# 4    2020-01-25         3       0
# ..          ...       ...     ...
# 715  2022-01-05  57745959  830549
# 716  2022-01-06  58505177  832508
# 717  2022-01-07  59405224  835159
# 718  2022-01-08  59851464  835837
# 719  2022-01-09  60166922  836238
#
# [720 rows x 3 columns]

# %%
import pandas as pd
df2=pd.read_csv("/us-counties-recent.csv")
df2
# Out:
#              date      county    state     fips  cases  deaths
# 0      2021-12-11     Autauga  Alabama   1001.0  10596   158.0
# 1      2021-12-11     Baldwin  Alabama   1003.0  38307   591.0
# 2      2021-12-11     Barbour  Alabama   1005.0   3716    81.0
# 3      2021-12-11        Bibb  Alabama   1007.0   4379    95.0
# 4      2021-12-11      Blount  Alabama   1009.0  10857   193.0
# ...           ...         ...      ...      ...    ...     ...
# 97515  2022-01-09  Sweetwater  Wyoming  56037.0   8506   110.0
# 97516  2022-01-09       Teton  Wyoming  56039.0   7025    14.0
# 97517  2022-01-09       Uinta  Wyoming  56041.0   4264    34.0
# 97518  2022-01-09    Washakie  Wyoming  56043.0   1914    39.0
# 97519  2022-01-09      Weston  Wyoming  56045.0   1263    16.0
#
# [97520 rows x 6 columns]

# %%
df_merged = pd.merge(df1, df2, how='inner')
df_merged
df
# Out:
#              date      county    state     fips  cases  deaths
# 0      2021-12-11     Autauga  Alabama   1001.0  10596   158.0
# 1      2021-12-11     Baldwin  Alabama   1003.0  38307   591.0
# 2      2021-12-11     Barbour  Alabama   1005.0   3716    81.0
# 3      2021-12-11        Bibb  Alabama   1007.0   4379    95.0
# 4      2021-12-11      Blount  Alabama   1009.0  10857   193.0
# ...           ...         ...      ...      ...    ...     ...
# 97515  2022-01-09  Sweetwater  Wyoming  56037.0   8506   110.0
# 97516  2022-01-09       Teton  Wyoming  56039.0   7025    14.0
# 97517  2022-01-09       Uinta  Wyoming  56041.0   4264    34.0
# 97518  2022-01-09    Washakie  Wyoming  56043.0   1914    39.0
# 97519  2022-01-09      Weston  Wyoming  56045.0   1263    16.0
#
# [97520 rows x 6 columns]

# %% [markdown]
# 1.

# %%
# Count the number of unique countries in df1
num_countries = df2['county'].nunique()
print("Number of countries:", num_countries)

# Count the number of unique states in df2
num_states = df2['state'].nunique()
print("Number of states:", num_states)
# Out:
# Number of countries: 1930
# Number of states: 56
